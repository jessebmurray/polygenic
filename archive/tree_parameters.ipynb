# %%
import imp 
import tree_functions as tree
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
import time
import shelve

# %%
n = 600
z_range = 6

mean_gen = 0
sd_gen = 1

ROUND_NUMBER = 6
perc = 0.1

figures_file = 'figures/'

# %%
# parent_distribution = tree.normal_distribution(100, z_range, mean_gen, sd_gen)

# %%
imp.reload(tree)
# Out:
# <module 'tree_functions' from '/Users/jessemurray/Desktop/Tree/tree_functions.py'>

# %%
wide_parent = tree.normal_distribution(600, 6, 0, 1)
# wide_r = np.arange(0.15, 1.2, 0.05)
wide_r = np.arange(0.65, 1.2, 0.05)
wide_r_s = np.arange(0.4, 1.45, 0.05)

# %%
len(wide_r), len(wide_r_s)
# Out:
# (11, 21)

# %%
wide = tree.get_ratios(wide_parent, wide_r, wide_r_s)
# Out:
# i = 0 r = 0.65
# Ratios:
# [[[0.65, 0.4], 0.7559213898043521], [[0.65, 0.45], 0.7835286512570497], [[0.65, 0.5], 0.813275556241461], [[0.65, 0.55], 0.8449359225407282], [[0.65, 0.6], 0.8783006357354987], [[0.65, 0.65], 0.9131711438314235], [[0.65, 0.7], 0.9493418755412905], [[0.65, 0.75], 0.9865747895122337], [[0.65, 0.8], 1.0245784524057195], [[0.65, 0.85], 1.0630043100627438], [[0.65, 0.9], 1.101463390316351], [[0.65, 0.95], 1.1395564732271388], [[0.65, 1.0], 1.176906712520765], [[0.65, 1.05], 1.2131858467415775], [[0.65, 1.1], 1.2481298894729045], [[0.65, 1.15], 1.2815443623418568], [[0.65, 1.2], 1.3133014664910325], [[0.65, 1.25], 1.3433322352030879], [[0.65, 1.3], 1.371616348674545], [[0.65, 1.35], 1.398171543477937], [[0.65, 1.4], 1.4230437956297133]]

# %%
print(tree.st_dev_of_distribution(wide_parent))

# %% [markdown]
# Up to i = 8, or r = 0.55. We can now start with r = 0.60 and continue. The run time has been about 11 hours. So we can expect it to take about 13 hours or so to finish.

# %%
print(ratios_60)
# Out:
# [[[0.15, 0.4], 0.4265426710990767], [[0.15, 0.45], 0.4737495646913922], [[0.15, 0.5], 0.5214773562528404], [[0.15, 0.55], 0.5695947821955025], [[0.15, 0.6], 0.6180076936721534], [[0.15, 0.65], 0.6666356130833248], [[0.15, 0.7], 0.7153820653055578], [[0.15, 0.75], 0.7641016411484136], [[0.15, 0.8], 0.8125776934168755], [[0.15, 0.85], 0.8605229026101294], [[0.15, 0.9], 0.907602943423931], [[0.15, 0.95], 0.9534728409233615], [[0.15, 1.0], 0.9978130649981629], [[0.15, 1.05], 1.0403563819377821], [[0.15, 1.1], 1.0809022729646915], [[0.15, 1.15], 1.1193200861928592], [[0.15, 1.2], 1.1555441335544419], [[0.15, 1.25], 1.1895642045893604], [[0.15, 1.3], 1.2214143075369155], [[0.15, 1.35], 1.251161527420048], [[0.15, 1.4], 1.2788960657476491], [[0.2, 0.4], 0.4460621887714843], [[0.2, 0.45], 0.49139747255002786], [[0.2, 0.5], 0.5375606561753975], [[0.2, 0.55], 0.5843552360402143], [[0.2, 0.6], 0.6316378198154744], [[0.2, 0.65], 0.6792907084704258], [[0.2, 0.7], 0.7271893325290998], [[0.2, 0.75]
# ...

# %%
narrow_parent = tree.normal_distribution(600, 6, 0, 1)
narrow_r = np.arange(0.275, 0.8, 0.05)
narrow_r_s = np.arange(0.675, 1.2, 0.05)

# %%
narrow = tree.get_ratios(narrow_parent, narrow_r, narrow_r_s)

# %%
print(tree.st_dev_of_distribution(wide_parent))
# 0.9867584620423371

# %%
wide

# %%
narrow
