# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load data

# %%
df = pd.read_table('data/pearson-lee-sons.txt')
x_raw = df.Father.to_numpy()
y_raw = df.Son.to_numpy()

# %%
x_raw.std() * 2.54
# Out:
# 6.96873126848125

# %%
y_raw.std() * 2.54
# Out:
# 7.146025255451129

# %% [markdown]
# Karl Pearson organized the collection of data on over 1100 families in England in the period 1893 to 1898. This particular data set gives the Heights in inches of mothers and their daughters, with up to two daughters per mother. All daughters are at least age 18, and all mothers are younger than 65. Data were given in the source as a frequency table to the nearest inch. Rounding error has been added to remove discreteness from graph.

# %%
print(x_raw.size)
# Out:
# 1078

# %% [markdown]
# ### Standardize

# %%
x = (x_raw - x_raw.mean()) / x_raw.std()
y = (y_raw - x_raw.mean()) / x_raw.std()

# %%
plt.figure(figsize=(6, 6))
plt.scatter(x, y, alpha=0.5,
           facecolors='none', edgecolors='#1f77b4')
plt.grid(alpha=0.5)
plt.xlabel('Parent score')
plt.ylabel('Offspring score')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %% [markdown]
# ## Linear Model Verification

# %% [markdown]
# ### 1. Check normality of $X_0$

# %%
plt.hist(x, bins=50);

# %%
def normal_qq(data):
    n = data.size
    theor = data.std() * stats.norm.ppf(
        np.arange(1, n + 1) / (n + 1)) + data.mean()
    return theor, np.sort(data)    

def plt_normal_qq(data, lim=3.5):
    x_theor, x_sample = normal_qq(data)
    
    plt.plot([-5, 5], [-5, 5], color='grey')
    plt.scatter(x_theor, x_sample, alpha=0.6, 
                facecolors='none', edgecolors='#1f77b4')
    plt.xlim([-lim, lim])
    plt.ylim([-lim, lim])
    plt.grid(alpha=0.3)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.xlabel('Theoretical')
    plt.ylabel('Observed')

# %%
plt.figure(figsize=(5, 5))
plt_normal_qq(x, lim=4)
plt.tight_layout()
# plt.savefig('latex/figures/qq_pearson_x-sons.png', dpi=300)

# %%
print(np.round(stats.skew(x), 5))
print(np.round(stats.kurtosis(x), 5))
# Out:
# -0.08815
# -0.16035

# %% [markdown]
# #### Tests of normality for skew and kurtosis

# %%
stats.skewtest(x)
# Out:
# SkewtestResult(statistic=-1.1873296087790617, pvalue=0.23509763344231527)

# %%
stats.kurtosistest(x)
# Out:
# KurtosistestResult(statistic=-1.0683781547409283, pvalue=0.28534996696925896)

# %%
stats.normaltest(x)
# Out:
# NormaltestResult(statistic=2.5511834814110705, pvalue=0.2792656664558387)

# %% [markdown]
# ### 2. Estimate $r$ and $rs$

# %%
from sklearn.linear_model import LinearRegression

lmb = LinearRegression(fit_intercept=True)
lmb.fit(x.reshape(-1, 1), y)
# Out:
# LinearRegression()

# %%
print('Using SkLearn software:', lmb.coef_)
r = 1 / np.dot(x, x) * np.dot(x, y)
print('Using linear algebra:  ', r)
# Out:
# Using SkLearn software: [0.51409304]
# Using linear algebra:   0.5140930386233066

# %%
X = np.concatenate([[np.ones(x.size)], [x]]).T

Y = y.reshape(-1, 1)

B = np.linalg.inv(X.T @ X) @ X.T @ Y

print(B[0][0])
print(B[1][0])
# Out:
# 0.3633819119501897
# 0.5140930386233078

# %%
epsi = y - r*x

# %%
rs = epsi.std()

# %%
print(epsi.mean())
# Out:
# 0.3633819119501897

# %%
epsi.mean() * x_raw.std() * 2.54
# Out:
# 2.532310892207787

# %%
(y_raw.mean() - x_raw.mean()) * 2.54
# Out:
# 2.532310892207774

# %%
print(np.round(r, 5))
print(np.round(rs, 5))
# Out:
# 0.51409
# 0.88726

# %% [markdown]
# ### 3. Verify normality of the residuals

# %%
plt.hist(epsi, bins=50);

# %%
plt.figure(figsize=(5, 5))
plt_normal_qq(epsi - epsi.mean(), lim=4)
plt.tight_layout()
# plt.savefig('latex/figures/qq_pearson_epsi-sons.png', dpi=300)

# %%
print(np.round(stats.skew(epsi), 5))
# Out:
# -0.05127

# %%
print(np.round(stats.kurtosis(epsi), 5))
# Out:
# 0.82237

# %% [markdown]
# #### Tests of normality for skew and kurtosis

# %%
stats.skewtest(epsi)
# Out:
# SkewtestResult(statistic=-0.6914315216916881, pvalue=0.4892944006361375)

# %%
stats.kurtosistest(epsi)
# Out:
# KurtosistestResult(statistic=4.138445316508387, pvalue=3.496671880723241e-05)

# %%
stats.normaltest(epsi)
# Out:
# NormaltestResult(statistic=17.60480718691909, pvalue=0.0001503712091255954)

# %% [markdown]
# ### Check if the residual varies with the parent score

# %%
plt.figure(figsize=(6, 6))
plt.scatter(x, epsi - epsi.mean(), alpha=0.5,
           facecolors='none', edgecolors='#1f77b4')
plt.axhline(y=0, color='grey')
plt.grid(alpha=0.4)
plt.xlabel('Parent score')
plt.ylabel('Offspring residual')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
x_binned = np.digitize(x, bins)

# %%
epsi_means = np.array([epsi[x_binned == i].mean() - epsi.mean() 
 for i in range(bins.size+1)])

epsi_sds = np.array([epsi[x_binned == i].std() 
                     for i in range(bins.size+1)])

# %%
true_bins = np.arange(-2.25, 2.75, 0.5)

# %% [markdown]
# #### SD confidence interval

# %%
plt.figure(figsize=(6, 6))
plt.plot(true_bins, epsi_means, color='black')
plt.errorbar(true_bins, epsi_means,
            yerr=epsi_sds, color='grey', alpha=0.8)
# plt.ylim(-0.3, 0.3)
plt.axhline(y=0, color='grey')
# plt.grid(alpha=0.4)
plt.xlabel('Parent score')
plt.ylabel('Offspring residual')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %% [markdown]
# ### Normal confidence interval

# %%
epsi_cis = np.array([stats.norm.interval(alpha=0.95, 
                        loc=np.mean(epsi[x_binned == i] - epsi.mean()), 
                    scale=stats.sem(epsi[x_binned == i] - epsi.mean())) 
                     for i in range(bins.size+1)])

epsi_cis = np.abs(epsi_cis - epsi_means.reshape(-1, 1))

# %%
plt.figure(figsize=(5, 4))
plt.plot(true_bins, epsi_means, color='black', linewidth=2)
plt.errorbar(true_bins, epsi_means,
            yerr=epsi_cis.T, color='grey', alpha=1, linewidth=1.4)
# plt.ylim(-0.3, 0.3)
plt.axhline(y=0, color='grey')
plt.grid(alpha=0.3)
plt.xlabel('Parent score')
plt.ylabel('Offspring residual')
# plt.gca().set_aspect('equal', adjustable='box')
plt.tight_layout()
# plt.savefig('latex/figures/pearson_residuals_by_score-sons.png', dpi=300)
plt.show()

# %% [markdown]
# ### Population variance dynamics

# %%
r, rs
# Out:
# (0.5140930386233066, 0.887264518802002)

# %%
r**2 + rs**2
# Out:
# 1.0515299786858927

# %%
y.var()
# Out:
# 1.0515299786858936

# %%
r**2 + rs**2
# Out:
# 1.0515299786858927

# %%
y.var()
# Out:
# 1.0515299786858936

# %%
len('05152997868589')
# Out:
# 14

# %%
print(y.std())
print(x.std())
# Out:
# 1.025441357994641
# 1.0

# %% [markdown]
# #### The offspring heights are indeed normal

# %%
stats.skewtest(y)
# Out:
# SkewtestResult(statistic=-0.4943864416613085, pvalue=0.6210332874918318)

# %%
stats.kurtosistest(y)
# Out:
# KurtosistestResult(statistic=2.9813610649654287, pvalue=0.0028697022712870454)

# %%
stats.normaltest(y)
# Out:
# NormaltestResult(statistic=9.132931753390325, pvalue=0.01039463078631299)

# %%
plt.figure(figsize=(5, 5))
plt_normal_qq(y, lim=5)

# %% [markdown]
# #### Test for equality of variances

# %%
stats.levene(x, y, center='mean')
# Out:
# LeveneResult(statistic=0.10692246285726714, pvalue=0.7437072172197279)

# %%
def f_test(x, y):
    x = np.array(x)
    y = np.array(y)
    f = np.var(x, ddof=1)/np.var(y, ddof=1) #calculate F test statistic 
    dfn = x.size-1 #define degrees of freedom numerator 
    dfd = y.size-1 #define degrees of freedom denominator 
    p = 1 - stats.f.cdf(f, dfn, dfd) #find p-value of F test statistic 
    return f, p

# %%
f_test(y, x)
# Out:
# (1.0515299786858938, 0.2048994603801707)

# %% [markdown]
# ### Miscellaneous

# %%
stats.ttest_ind(x, y, equal_var=False)
# Out:
# Ttest_indResult(statistic=-8.325919805445947, pvalue=1.4680170030149197e-16)

# %%
stats.ttest_ind(x, y - epsi.mean(), equal_var=False)
# Out:
# Ttest_indResult(statistic=-1.8273668033836014e-14, pvalue=0.9999999999999853)

# %%
stats.ttest_1samp(epsi, 0)
# Out:
# Ttest_1sampResult(statistic=13.440581003601935, pvalue=3.4679890397655524e-38)

# %%
y.var()
# Out:
# 1.0515299786858936

# %%
epsi.mean()
# Out:
# 0.3633819119501897

# %%
np.cov(x, y)
# Out:
# array([[1.00092851, 0.51457038],
#        [0.51457038, 1.05250633]])
